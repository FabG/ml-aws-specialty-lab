# %%
import numpy as np
import boto3
import sagemaker
import io
import sagemaker.amazon.common as smac
import os
import pandas as pd

# Read csv from s3.
# Download from your S3 bucket the bike share data CSV file based on the publically available bike share data from the ML repository curated by the University of California, Irvine
from io import StringIO
s3 = boto3.resource('s3')
bucket = 'machine-learning-exam' # place the day.csv file in a bucket in your account
object_key = 'day.csv'

# Load the data into a pandas dataframe 
csv_obj = s3.Object(bucket, object_key)
csv_string = csv_obj.get()['Body'].read().decode('utf-8')

dataset = pd.read_csv(StringIO(csv_string))
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Convert categorical date field
dataset['dteday'] = dataset['dteday'].str.replace("-","")
dataset.head()
# Out:
#    instant    dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  20110101       1   0     1        0        6           0
# 1        2  20110102       1   0     1        0        0           0
# 2        3  20110103       1   0     1        0        1           1
# 3        4  20110104       1   0     1        0        2           1
# 4        5  20110105       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Randomize the data and split it between train and test datasets on a 70% 30% split respectively
train_data, test_data = np.split(dataset.sample(frac=1, random_state=1729), [int(0.7 * len(dataset))])
print(train_data.shape, test_data.shape)
# Out:
# (511, 16) (220, 16)

# %%
# Get the features and labels.
feature_dataset = train_data[['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
                           'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered' ]]
features = np.array(feature_dataset.values).astype('float32')

label_dataset= train_data[['cnt']]
labels = np.array(label_dataset.values).astype('float32')
labels_vec = np.squeeze(np.asarray(labels))

# %%
# Setup protoBuf
buffer = io.BytesIO()
smac.write_numpy_to_dense_tensor(buffer, features, labels_vec)
buffer.seek(0)

prefix = 'realestate'
key = 'linearregression'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buffer)
s3_training_data_location = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('training dataset will be uploaded to: {}'.format(s3_training_data_location))
# Out:
# training dataset will be uploaded to: s3://machine-learning-exam/realestate/train/linearregression

# %%
output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('model artifacts will be uploaded to: {}'.format(output_location))
# Out:
# model artifacts will be uploaded to: s3://machine-learning-exam/realestate/output

# %%
# Get the Linear Learner container instance
from sagemaker.amazon.amazon_estimator import get_image_uri
linear_container = get_image_uri(boto3.Session().region_name, 'linear-learner')

# %%
# Train the model
from sagemaker import get_execution_role

role = get_execution_role()

sagemaker_session = sagemaker.Session()

# Provide the container, role, instance type and model output location
linear = sagemaker.estimator.Estimator(linear_container,
                                       role=role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sagemaker_session)

# Provide the number of features identified during data preparation
# Provide the predictor_type 

linear.set_hyperparameters(feature_dim=15,
                           mini_batch_size=4,
                           predictor_type='regressor')

# Train the model using the previously prepared test data and validate the 
# data by providing the validation data.

linear.fit({'train': s3_training_data_location})
# Out:
# 2020-02-14 19:06:55 Starting - Starting the training job...
# 2020-02-14 19:06:56 Starting - Launching requested ML instances......
# 2020-02-14 19:08:02 Starting - Preparing the instances for training......
# 2020-02-14 19:09:24 Downloading - Downloading input data...
# 2020-02-14 19:09:47 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# [02/14/2020 19:10:09 INFO 140163623442240] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/14/2020 19:10:09 INFO 140163623442240] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'15', u'mini_batch_size': u'4', u'predictor_type': u'regressor'}
# [02/14/2020 19:10:09 INFO 140163623442240] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'4', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/14/2020 19:10:09 WARNING 140163623442240] Loggers have already been setup.
# Process 1 is a worker.
# [02/14/2020 19:10:09 INFO 140163623442240] Using default worker.
# [2020-02-14 19:10:09.806] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 14, "num_examples": 1, "num_bytes":
196] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 140, "num_examples": 128, "num_bytes": 53144}
# [02/14/2020 19:10:47 INFO 140163623442240] #train_score (algo-1) : ('mse_objective', 1.6779703935298433)
# [02/14/2020 19:10:47 INFO 140163623442240] #train_score (algo-1) : ('mse', 1.6779703935298433)
# [02/14/2020 19:10:47 INFO 140163623442240] #train_score (algo-1) : ('absolute_loss', 1.043970156555773)
# [02/14/2020 19:10:47 INFO 140163623442240] #quality_metric: host=algo-1, train mse_objective <loss>=1.67797039353
# [02/14/2020 19:10:47 INFO 140163623442240] #quality_metric: host=algo-1, train mse <loss>=1.67797039353
# [02/14/2020 19:10:47 INFO 140163623442240] #quality_metric: host=algo-1, train absolute_loss <loss>=1.04397015656
# [02/14/2020 19:10:47 INFO 140163623442240] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [02/14/2020 19:10:47 INFO 140163623442240] Saved checkpoint to "/tmp/tmpRVYAEU/mx-mod-0000.params"
# [02/14/2020 19:10:47 INFO 140163623442240] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 37502.739906311035, "sum": 37502.739906311035, "min": 37502.739906311035}, "finalize.time": {"count": 1, "max": 145.23792266845703, "sum": 145.23792266845703, "min": 145.23792266845703}, "initialize.time": {"count": 1, "max": 421.84996604919434, "sum": 421.84996604919434, "min": 421.84996604919434}, "check_early_stopping.time": {"count": 15, "max": 1.1441707611083984, "sum": 15.458822250366211, "min": 0.90789794921875}, "setuptime": {"count": 1, "max": 26.974916458129883, "sum": 26.974916458129883, "min": 26.974916458129883}, "update.time": {"count": 15, "max": 2790.6999588012695, "sum": 36829.829931259155, "min": 2144.9930667877197}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1581707447.206031, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1581707409.791645}
# Training seconds: 90
# Billable seconds: 90

# %%
# Deploy the model
linear_predictor = linear.deploy(initial_instance_count=1,
                                 instance_type='ml.c4.xlarge',
                                 endpoint_name='bikeshare-sagemaker-regression-v1')
# Out:
# ------

# %%
# Get prediction using the test data
from sagemaker.predictor import csv_serializer, json_deserializer

linear_predictor.content_type = 'text/csv'
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer

test_feature_dataset = test_data[['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
                           'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered']]

test_actuals = np.array(test_data['cnt'].astype('float32'))
test_features = np.array(test_feature_dataset.values).astype('float32')

predictions = []
actuals = []
for tf, actual in zip(test_features, test_actuals):
    prediction = linear_predictor.predict(tf)
    predictions.append(prediction['predictions'][0]['score'])
    actuals.append(actual)
    print('prediction: ', prediction['predictions'][0]['score'], '\t\tactual: ', str(actual))
# Out:
# prediction:  799.390625 		actual:  801.0
# prediction:  5216.703125 		actual:  5217.0
# prediction:  7765.5625 		actual:  7767.0
# prediction:  6850.9375 		actual:  6852.0
# prediction:  2209.953125 		actual:  2209.0
# prediction:  6289.296875 		actual:  6290.0
# prediction:  4790.71875 		actual:  4792.0
# prediction:  1866.8125 		actual:  1865.0
# prediction:  5670.359375 		actual:  5668.0
# prediction:  4492.265625 		actual:  4492.0
# prediction:  4368.203125 		actual:  4367.0
# prediction:  2402.453125 		actual:  2402.0
# prediction:  3847.546875 		actual:  3846.0
# prediction:  4787.96875 		actual:  4788.0
# prediction:  3189.03125 		actual:  3190.0
# prediction:  3006.515625 		actual:  3005.0
# prediction:  7284.65625 		actual:  7286.0
# prediction:  2131.25 		actual:  2132.0
# prediction:  5462.21875 		actual:  5464.0
# prediction:  4984.09375 		actual:  4985.0
# prediction:  6304.640625 		actual:  6304.0
# prediction:  5532.03125 		actual:  5532.0
# prediction:  8008.15625 		actual:  8009.0
# prediction:  3000.46875 		actual:  2999.0
# prediction:  4337.140625 		actual:  4338.0
# prediction:  3509.8125 		actual:  3510.0
# prediction:  6881.859375 		actual:  6883.0
# prediction:  4760.390625 		actual:  4760.0
# prediction:  4360.484375 		actual:  4362.0
# prediction:  2894.046875 		actual:  2895.0
# prediction:  6770.234375 		actual:  6770.0
# prediction:  4108.25 		actual:  4109.0
# prediction:  3348.859375 		actual:  3351.0
# prediction:  7331.828125 		actual:  7333.0
# prediction:  7864.484375 		actual:  7865.0
# prediction:  6073.578125 		actual:  6073.0
# prediction:  3543.296875 		actual:  3544.0
# prediction:  5099.53125 		actual:  5099.0
# prediction:  4292.859375 		actual:  4294.0
# prediction:  5204.546875 		actual:  5204.0
# prediction:  4256.953125 		actual:  4258.0
# prediction:  6535.609375 		actual:  6536.0
# prediction:  6043.4375 		actual:  6043.0
# prediction:  6595.84375 		actual:  6598.0
# prediction:  1707.96875 		actual:  1708.0
# prediction:  3293.046875 		actual:  3292.0
# prediction:  6039.125 		actual:  6041.0
# prediction:  3193.859375 		actual:  3194.0
# prediction:  5611.375 		actual:  5611.0
# prediction:  4904.171875 		actual:  4905.0
# prediction:  3577.71875 		actual:  3577.0
# prediction:  4658.96875 		actual:  4660.0
# prediction:  1544.078125 		actual:  1543.0
# prediction:  4661.8125 		actual:  4661.0
# prediction:  5381.125 		actual:  5382.0
# prediction:  6829.4375 		actual:  6830.0
# prediction:  5202.15625 		actual:  5202.0
# prediction:  3659.453125 		actual:  3659.0
# prediction:  2178.15625 		actual:  2177.0
# prediction:  5043.75 		actual:  5046.0
# prediction:  3243.9375 		actual:  3243.0
# prediction:  4077.21875 		actual:  4075.0
# prediction:  5461.5625 		actual:  5459.0
# prediction:  4332.28125 		actual:  4332.0
# prediction:  3767.1875 		actual:  3767.0
# prediction:  2192.625 		actual:  2192.0
# prediction:  3818.953125 		actual:  3820.0
# prediction:  1651.375 		actual:  1650.0
# prediction:  6734.65625 		actual:  6734.0
# prediction:  3164.90625 		actual:  3163.0
# prediction:  4374.125 		actual:  4375.0
# prediction:  3246.90625 		actual:  3249.0
# prediction:  6272.0625 		actual:  6273.0
# prediction:  7590.671875 		actual:  7591.0
# prediction:  3810.015625 		actual:  3811.0
# prediction:  2132.171875 		actual:  2133.0
# prediction:  3389.484375 		actual:  3389.0
# prediction:  1549.046875 		actual:  1550.0
# prediction:  5408.765625 		actual:  5409.0
# prediction:  4033.796875 		actual:  4035.0
# prediction:  6917.421875 		actual:  6917.0
# prediction:  796.46875 		actual:  795.0
# prediction:  6267.25 		actual:  6269.0
# prediction:  1100.296875 		actual:  1096.0
# prediction:  3331.90625 		actual:  3331.0
# prediction:  4646.921875 		actual:  4649.0
# prediction:  2475.46875 		actual:  2475.0
# prediction:  6966.0 		actual:  6966.0
# prediction:  3743.15625 		actual:  3744.0
# prediction:  4842.34375 		actual:  4845.0
# prediction:  5537.46875 		actual:  5538.0
# prediction:  2794.46875 		actual:  2792.0
# prediction:  7664.328125 		actual:  7665.0
# prediction:  4725.625 		actual:  4727.0
# prediction:  7400.25 		actual:  7403.0
# prediction:  1943.421875 		actual:  1944.0
# prediction:  706.390625 		actual:  705.0
# prediction:  7853.640625 		actual:  7852.0
# prediction:  3489.4375 		actual:  3487.0
# prediction:  3777.953125 		actual:  3777.0
# prediction:  2169.875 		actual:  2169.0
# prediction:  754.25 		actual:  754.0
# prediction:  7569.1875 		actual:  7570.0
# prediction:  1538.6875 		actual:  1536.0
# prediction:  5167.984375 		actual:  5169.0
# prediction:  1948.90625 		actual:  1951.0
# prediction:  7734.328125 		actual:  7736.0
# prediction:  1694.046875 		actual:  1693.0
# prediction:  1343.390625 		actual:  1341.0
# prediction:  4195.171875 		actual:  4195.0
# prediction:  1359.609375 		actual:  1360.0
# prediction:  5738.25 		actual:  5740.0
# prediction:  3624.265625 		actual:  3623.0
# prediction:  4991.375 		actual:  4991.0
# prediction:  4454.359375 		actual:  4456.0
# prediction:  6591.5625 		actual:  6591.0
# prediction:  5423.640625 		actual:  5423.0
# prediction:  4273.0 		actual:  4274.0
# prediction:  7422.859375 		actual:  7424.0
# prediction:  5509.171875 		actual:  5511.0
# prediction:  4340.125 		actual:  4339.0
# prediction:  6040.265625 		actual:  6043.0
# prediction:  4187.765625 		actual:  4187.0
# prediction:  5786.15625 		actual:  5786.0
# prediction:  4085.125 		actual:  4086.0
# prediction:  3647.1875 		actual:  3649.0
# prediction:  1815.109375 		actual:  1815.0
# prediction:  7383.5625 		actual:  7384.0
# prediction:  3829.65625 		actual:  3830.0
# prediction:  1605.15625 		actual:  1605.0
# prediction:  7701.40625 		actual:  7702.0
# prediction:  8394.78125 		actual:  8395.0
# prediction:  8172.78125 		actual:  8173.0
# prediction:  4824.484375 		actual:  4826.0
# prediction:  7693.203125 		actual:  7693.0
# prediction:  5894.859375 		actual:  5895.0
# prediction:  7445.59375 		actual:  7444.0
# prediction:  6685.953125 		actual:  6685.0
# prediction:  4590.328125 		actual:  4592.0
# prediction:  7592.0625 		actual:  7592.0
# prediction:  5584.21875 		actual:  5585.0
# prediction:  7416.796875 		actual:  7415.0
# prediction:  2078.1875 		actual:  2077.0
# prediction:  1510.375 		actual:  1510.0
# prediction:  3124.921875 		actual:  3126.0
# prediction:  2807.109375 		actual:  2808.0
# prediction:  2251.0 		actual:  2252.0
# prediction:  4627.421875 		actual:  4629.0
# prediction:  3113.578125 		actual:  3115.0
# prediction:  2731.734375 		actual:  2729.0
# prediction:  4687.78125 		actual:  4687.0
# prediction:  3908.5625 		actual:  3907.0
# prediction:  6367.9375 		actual:  6370.0
# prediction:  3670.828125 		actual:  3669.0
# prediction:  5727.296875 		actual:  5728.0
# prediction:  3374.0625 		actual:  3372.0
# prediction:  2703.90625 		actual:  2703.0
# prediction:  5557.46875 		actual:  5557.0
# prediction:  4122.984375 		actual:  4123.0
# prediction:  4308.6875 		actual:  4308.0
# prediction:  3944.046875 		actual:  3944.0
# prediction:  1688.21875 		actual:  1685.0
# prediction:  5559.09375 		actual:  5558.0
# prediction:  5846.03125 		actual:  5847.0
# prediction:  5034.828125 		actual:  5035.0
# prediction:  4400.390625 		actual:  4400.0
# prediction:  5339.484375 		actual:  5342.0
# prediction:  4045.578125 		actual:  4046.0
# prediction:  4843.34375 		actual:  4844.0
# prediction:  4569.671875 		actual:  4570.0
# prediction:  4600.59375 		actual:  4602.0
# prediction:  4630.828125 		actual:  4630.0
# prediction:  2425.953125 		actual:  2424.0
# prediction:  7569.984375 		actual:  7572.0
# prediction:  6234.5625 		actual:  6233.0
# prediction:  4971.625 		actual:  4972.0
# prediction:  4656.265625 		actual:  4656.0
# prediction:  1029.3125 		actual:  1027.0
# prediction:  958.640625 		actual:  959.0
# prediction:  4757.8125 		actual:  4758.0
# prediction:  4121.15625 		actual:  4120.0
# prediction:  3266.96875 		actual:  3267.0
# prediction:  4584.734375 		actual:  4586.0
# prediction:  4748.421875 		actual:  4748.0
# prediction:  6205.90625 		actual:  6207.0
# prediction:  7638.90625 		actual:  7639.0
# prediction:  2567.96875 		actual:  2566.0
# prediction:  4104.890625 		actual:  4105.0
# prediction:  4574.75 		actual:  4576.0
# prediction:  3053.953125 		actual:  3053.0
# prediction:  5699.328125 		actual:  5698.0
# prediction:  4073.328125 		actual:  4073.0
# prediction:  4304.921875 		actual:  4304.0
# prediction:  5985.171875 		actual:  5986.0
# prediction:  3895.71875 		actual:  3894.0
# prediction:  4784.015625 		actual:  4785.0
# prediction:  1588.140625 		actual:  1589.0
# prediction:  2936.3125 		actual:  2935.0
# prediction:  4460.859375 		actual:  4459.0
# prediction:  4577.53125 		actual:  4579.0
# prediction:  2368.21875 		actual:  2368.0
# prediction:  2802.53125 		actual:  2802.0
# prediction:  3749.1875 		actual:  3747.0
# prediction:  3572.734375 		actual:  3574.0
# prediction:  2594.296875 		actual:  2594.0
# prediction:  7040.453125 		actual:  7040.0
# prediction:  2235.21875 		actual:  2236.0
# prediction:  3785.796875 		actual:  3784.0
# prediction:  2733.140625 		actual:  2732.0
# prediction:  5255.671875 		actual:  5255.0
# prediction:  4341.09375 		actual:  4342.0
# prediction:  5528.203125 		actual:  5531.0
# prediction:  4066.546875 		actual:  4067.0
# prediction:  1890.6875 		actual:  1891.0
# prediction:  3376.5625 		actual:  3376.0
# prediction:  6977.0625 		actual:  6978.0
# prediction:  6657.6875 		actual:  6660.0
# prediction:  5112.59375 		actual:  5115.0
# prediction:  2162.65625 		actual:  2162.0
# prediction:  5875.5 		actual:  5875.0

# %%
# Get accuracy using Cosine Similarity method 
from numpy import dot
from numpy.linalg import norm
tolerance = 1e-10
accuracy = (dot(actuals, predictions)/(norm(actuals)*norm(predictions))) * 100
print('accuracy: ', accuracy)
# Out:
# accuracy:  100.00000313584616

# %%
# delete the endpoint
sagemaker.Session().delete_endpoint(linear_predictor.endpoint)
